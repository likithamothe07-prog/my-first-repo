# %% [markdown]
# Hardware is a physical machine which we can touch whereas software is set of instructions that tell hardware what to do.
# Examples of hardware is CPU, RAM, GPU.
# Examples of software is OS, Browser, code editor.
