# %% [markdown]
# <a href="https://colab.research.google.com/github/likithamothe07-prog/my-first-repo/blob/main/python_basics_Likitha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="Likitha"
age=25
height=5.3
is_student=True
print(name, age, height, is_student)
# Out:
# Likitha 25 5.3 True

# %%
print(f"Name: {name}| Age:{age}| Height: {height} | Is_student:{is_student}")
# Out:
# Name: Likitha| Age:25| Height: 5.3 | Is_student:True

# %%
age_in_months = age*12
age_in_days = age*365
remainder = age%7
power_of_two = age**2
print("Age in months:", age_in_months)
print("Age in days:", age_in_days)
print("Remainder when age is divided by 7:", remainder)
print("Power of age raised to 2:", power_of_two)
# Out:
# Age in months: 300
# Age in days: 9125
# Remainder when age is divided by 7: 4
# Power of age raised to 2: 625
